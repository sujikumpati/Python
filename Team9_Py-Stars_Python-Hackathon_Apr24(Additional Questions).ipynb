# %% [markdown]
# # Find the patient's outcome who had high CCI Score

# %%
import pandas as pd
import numpy as np

# %%
df_PatientHistory=pd.read_excel("Cardiac_Outcomes.xlsx","PatientHistory")
df_Hospitalization_Discharge = pd.read_excel("Cardiac_Outcomes.xlsx","Hospitalization_Discharge")
import matplotlib.pyplot as plt
df_Demography=pd.read_excel("Cardiac_Outcomes.xlsx","Demography")
df_Labs=pd.read_excel("Cardiac_Outcomes.xlsx","Labs")

# %% [markdown]
# # Q1. Plot a bar chart showing the number of patients having typeII respiratory failure.

# %%
RespiratoryFailure_Type = df_PatientHistory["type_II_respiratory_failure"].value_counts().to_frame('count')
RespiratoryFailure_Type
# Out:
#                              count
# type_II_respiratory_failure
# NonTypeII                     1894
# TypeII                         114

# %%
Patients_Counts=df_PatientHistory["inpatient_number"]
RespiratoryFailure_Type = df_PatientHistory["type_II_respiratory_failure"]
plt.hist(RespiratoryFailure_Type, bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('RespiratoryFailure_Type')
plt.ylabel('Patients_Counts')
plt.title('RespiratoryFailure of Patients')
plt.show()

# %%
plt.xticks(range(0, len(admissions_count), 5), admissions_count.index[::5].strftime('%Y-%m'))

# %% [markdown]
# # Q2.Count of patients having Dementia as per gender

# %%
df1=df_Demography    
df2=df_PatientHistory
df_Merged=pd.merge(df1,df2)
df_Merged
df_grouped=df_Merged.groupby(['dementia','gender']).size().unstack()
df_grouped
# Out:
# gender    Female  Male
# dementia
# 0           1112   781
# 1             51    64

# %% [markdown]
# # Q3.Visualize correlation between systolic_blood_pressure and diastolic_blood_pressure as per gender

# %%
import seaborn as sns
s=df_Labs
h=df_Labs["systolic_blood_pressure"]
m=df_Labs["diastolic_blood_pressure"]
sns.scatterplot(data=s, x=h,y=m, hue=df_Demography["gender"])
# Out:
# <Axes: xlabel='systolic_blood_pressure', ylabel='diastolic_blood_pressure'>

# %% [markdown]
# # Q4-Visualize the admission_ward as per gender?

# %%
l=df_Hospitalization_Discharge["admission_ward"]
p=df_Demography["gender"]
sns.histplot(data=l, x=l,kde=True,hue=p,palette=['pink','blue'])
# Out:
# <Axes: xlabel='admission_ward', ylabel='Count'>

# %% [markdown]
# # Q5 Visualize the CCI_score as per gender?

# %%
H_df = pd.read_excel('Cardiac_Outcomes.xlsx',"Hospitalization_Discharge")
p_df = pd.read_excel('Cardiac_Outcomes.xlsx',"Patient_Precriptions")
cardiac_df=pd.read_excel('Cardiac_Outcomes.xlsx',"CardiacComplications")
Res_df=pd.read_excel('Cardiac_Outcomes.xlsx',"Responsivenes")
patient_df=pd.read_excel('Cardiac_Outcomes.xlsx',"PatientHistory")
labs_df=pd.read_excel('Cardiac_Outcomes.xlsx',"Labs")
Demo_df=pd.read_excel('Cardiac_Outcomes.xlsx',"Demography")
import seaborn as sns
import pandas as pd
f=patient_df["CCI_score"]
p=Demo_df["gender"]
sns.catplot(data=f, x=p, y=f ,kind='box')

# %% [markdown]
# # Q6 Find the statistics (mean,median,std etc) of length of stay of each admissionward

# %%
import pandas as pd
H_df = pd.read_excel('Cardiac_Outcomes.xlsx',"Hospitalization_Discharge",usecols="C,I")
H_df.groupby(['admission_ward']).describe()
# Out:
#                dischargeDay
#                       count       mean        std  min  25%   50%   75%    max
# admission_ward
# Cardiology           1547.0   9.001939   6.802566  1.0  6.0   8.0  10.0   82.0
# GeneralWard           265.0   9.996226  10.857374  1.0  6.0   8.0  11.0  123.0
# ICU                    15.0  13.933333  14.611476  1.0  4.5   7.0  16.0   50.0
# Others                181.0  11.784530  11.079159  1.0  6.0  10.0  13.0  118.0

# %% [markdown]
# # Q7 Visualize the patients age as per gender?

# %%
import seaborn as sns
tips_df= df_Demography=pd.read_excel("cardiac_outcomes.xlsx","Demography")
male_count = tips_df['gender'].value_counts()['Male']
print("Number of males:", male_count)
female_count = tips_df['gender'].value_counts()['Female']
print("Number of females:", female_count)
sns.catplot(data = tips_df, x="ageCat", y="inpatient_number", hue="gender", kind="swarm")
# Out:
# Number of males: 845
# Number of females: 1163
# C:\Users\vijay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vijay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vijay\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
